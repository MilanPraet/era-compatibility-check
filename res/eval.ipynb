# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

chlight = pd.read_csv('chSmallTile.csv')
normal = pd.read_csv('SmallTile.csv')

chlight.describe()
# Out:
#         explored       fetched       tiles  routeTime      setupTime  \
# count  97.000000    105.000000  105.000000   97.00000      97.000000
# mean    8.144330   2089.257143    3.628571    2.76797    6953.405153
# std     0.777143   6774.358336    0.973269   23.39141   15561.036099
# min     6.000000      0.000000    0.000000    0.15160     480.414700
# 25%     8.000000    243.000000    4.000000    0.22680    2190.025700
# 50%     8.000000    578.000000    4.000000    0.26940    3413.409300
# 75%     8.000000   1448.000000    4.000000    0.42780    5067.078300
# max    12.000000  41344.000000    5.000000  230.74280  110615.620000
#
#          tileTime      route#
# count  105.000000  105.000000
# mean     2.195447   53.000000
# std     22.496634   30.454885
# min      0.000000    1.000000
# 25%      0.000000   27.000000
# 50%      0.000000   53.000000
# 75%      0.000000   79.000000
# max    230.521900  105.000000

# %%
normal.describe()
# Out:
#         explored       fetched       tiles  routeTime     setupTime  tileTime  \
# count  97.000000    105.000000  105.000000  97.000000     97.000000     105.0
# mean    8.185567   2087.714286    3.619048   0.423270   5337.683846       0.0
# std     0.768249   6774.387007    0.964574   0.444557   9835.883872       0.0
# min     8.000000      0.000000    0.000000   0.155900    488.976100       0.0
# 25%     8.000000    243.000000    4.000000   0.219400   1950.306500       0.0
# 50%     8.000000    570.000000    4.000000   0.294400   2746.715500       0.0
# 75%     8.000000   1448.000000    4.000000   0.438600   4049.263800       0.0
# max    12.000000  41343.000000    4.000000   2.742400  69949.985600       0.0
#
#            route#
# count  105.000000
# mean    53.000000
# std     30.454885
# min      1.000000
# 25%     27.000000
# 50%     53.000000
# 75%     79.000000
# max    105.000000

# %%
normalized = (chlight-chlight.mean())/chlight.std()
sns.heatmap(normalized, annot=True, annot_kws={"size": 7})
# Out:
# <AxesSubplot:>
